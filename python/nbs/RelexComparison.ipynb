# %%
# %load_ext autoreload
# %autoreload 1

# %%
import os, sys
sys.path.insert(0, str("../"))

from collections import defaultdict, Counter
from lxml import etree
from utils.tmutils import normalize_gene_names

# %%
import scispacy
import spacy
from spacy import displacy

nlp = spacy.load('/mnt/f/spacy/en_core_sci_lg-0.2.5/en_core_sci_lg/en_core_sci_lg-0.2.5/')
nlp_ent = spacy.load("/mnt/f/spacy/en_ner_bionlp13cg_md-0.2.5/en_ner_bionlp13cg_md/en_ner_bionlp13cg_md-0.2.5")

import textmining.MirGeneRelCheck
from intervaltree import Interval, IntervalTree

# %%
def analyse(testCase, dist=80):
    relCheck = textmining.MirGeneRelCheck.MirGeneRelCheck()

    doc = nlp(testCase[0])
    entDoc = nlp_ent(testCase[0])
    
    enttree = IntervalTree()
    for ent in entDoc.ents:
        enttree.addi(ent.start_char, ent.end_char, (ent.label_, ent.text))

    
    lWord = doc[testCase[1]]
    rWord = doc[testCase[2]]

    for t in doc:
        
        possTokenEnts = enttree.overlap(t.idx, t.idx+len(t.text))
        ents = set([x.data for x in possTokenEnts])
        
        print(t.idx, t.idx+len(t.text), t.i, t, t.pos_, t.dep_, t.head, t.head.idx, ents)

    print(lWord, rWord)

    if not "mir" in str(lWord).lower() and not "let" in str(lWord).lower():
        tmp = lWord
        lWord = rWord
        rWord = tmp
        
    print(lWord, rWord)
    
    checkResults = relCheck.checkRelation(doc, lWord, rWord, verbose=True)
    print(checkResults)
    
    displacy.render(doc, style="dep", options={"compact": True, "distance": dist})
    
    entDoc = nlp_ent(testCase[0])
    
    
    displacy.render(entDoc, style="ent", options={"compact": True, "distance": dist})
    
    return enttree

# %%
normGeneSymbols = normalize_gene_names(path="../hgnc_no_withdrawn.syn")

# %%
testfile="test"

relexFile = "scai_"+testfile+"_relex.out"
scaiFile = "miRNA_"+testfile+"_fixed.xml"

# %%
relexAccepted = []

with open("../relexfiles/"+relexFile) as fin:

    wasRelation = False
    curSentID = None
    for line in fin:

        if line.startswith(">"):
            curSentID = line.strip()[1:]

        if line.startswith("#RELATIONS:"):
            wasRelation = True
            continue

        if wasRelation:
            relexAccepted.append(curSentID)

        wasRelation = False

    print("Relex Hits", len(relexAccepted))
# Out:
# Relex Hits 75

# %%
def printStats(outfile):
    print("Total:     ", totalChecks, file=outfile)
    print(file=outfile)
    print(file=outfile)
    print(file=outfile)
    print(file=outfile)
    print("T,T", elemCaseCounter[(True, True)], file=outfile)
    print("T,F", elemCaseCounter[(True, False)], file=outfile)
    print("F,T", elemCaseCounter[(False, True)], file=outfile)
    print("F,F", elemCaseCounter[(False, False)], file=outfile)

    precision = elemCaseCounter[(True, True)] / (elemCaseCounter[(True, True)]+elemCaseCounter[(True, False)])
    recall = elemCaseCounter[(True, True)] / (elemCaseCounter[(True, True)]+elemCaseCounter[(False, True)])

    f1 = 2* precision * recall / (precision+recall)

    specificity = elemCaseCounter[(False, False)] / (elemCaseCounter[(True, False)] + elemCaseCounter[(False, False)])

    print("precision", precision, file=outfile)
    print("recall", recall, file=outfile)
    print("specificity", specificity, file=outfile)
    print("f1", f1, file=outfile)

# %%
def scoreAnalysis(printCase=(True, False)):
    correctIdentified = 0
    incorrectIdentified = 0
    totalChecks = 0
    incorrectClass = Counter()

    relationNum = 0
    elemCaseCounter = Counter()

    with open(os.path.join("../scai_corpus", scaiFile), 'r') as fin:
        tree = etree.parse(fin)
        root = tree.getroot()
        scaiPairs = []

        for elem in root.findall(".//document"):

            pmid = elem.attrib['origId']

            for sentElem in elem:

                allEntities = sentElem.findall(".//entity")
                allPairs = sentElem.findall(".//pair")

                sentText = sentElem.attrib["text"]

                entId2elem = {}

                for entity in allEntities:
                    entId = entity.attrib['id']
                    entText = entity.attrib['text']
                    entType = entity.attrib['type']
                    entOffset = tuple([int(x) for x in entity.attrib['charOffset'].split("-")])

                    if entType in ["Specific_miRNAs", "Genes/Proteins"]:

                        if "Genes" in entType:
                            if entText in normGeneSymbols:
                                entText = normGeneSymbols[entText]
                            elif entText.upper() in normGeneSymbols:
                                gene = normGeneSymbols[entText.upper()]
                        else:
                            try:
                                entText = miRNA(entText).getStringFromParts([miRNAPART.MATURE, miRNAPART.ID, miRNAPART.PRECURSOR])
                            except:
                                pass

                        entTuple = (entText, entType, (entOffset[0], entOffset[1]+1))
                        entId2elem[entId] = entTuple


                        sentEntText = sentText[entTuple[2][0]:entTuple[2][1]]

                for pair in allPairs:

                    validInteraction = pair.attrib['interaction'].lower() == "true"
                    pairE1 = pair.attrib['e1']
                    pairE2 = pair.attrib['e2']

                    #if pairInt == 'true':
                    if pairE1 in entId2elem and pairE2 in entId2elem:

                        totalChecks += 1

                        e1 = entId2elem[pairE1]
                        e2 = entId2elem[pairE2]

                        if not e1[1] in ["Specific_miRNAs"]:

                            tmp=e1
                            e1=e2
                            e2=tmp


                        relationID = pair.attrib["id"]
                        relationID = "{}.0.0".format(relationNum)

                        relationNum += 1
                        #print(relationID, sentText.strip().rstrip(".").replace("/", ","), sep="\t", file=sentFile)

                        #8652807.2.10    protein 0       6:16202 55-60   tumor
                        e1Word = sentText[e1[2][0]:e1[2][1]]
                        e2Word = sentText[e2[2][0]:e2[2][1]]

                        #print(relationID, len(relationID) + e1[2][0]+1, e1[2][1]-e1[2][0], e1Word, "protein", relationID + "_" + e1[1], sep="\t", file=synFile)
                        #print(relationID, len(relationID) + e2[2][0]+1, e2[2][1]-e2[2][0], e2Word, "protein", relationID + "_" + e2[1], sep="\t", file=synFile)


                        validInteraction = pair.attrib['interaction'].lower() == "true"
                        acceptInteraction = relationID in relexAccepted

                        elemCase = (acceptInteraction, validInteraction)
                        elemCaseCounter[elemCase] += 1

                        if elemCase == printCase:

                            print(elemCase, str((sentText.strip(), e1Word, e2Word)))

    printStats(sys.stdout)

# %%
scoreAnalysis(printCase=(True, False))
# Out:
# (True, False) ('Moreover, the levels of the apl-1 transcription are modulated by the activity of let-7 family microRNAs.', 'let-7', 'apl-1')
# (True, False) ('C. elegans apl-1 shows significant genetic interactions with let-7 family microRNAs and let-7-targeted heterochronic genes, hbl-1, lin-41 and lin-42.', 'let-7', 'apl-1')
# (True, False) ('C. elegans apl-1 shows significant genetic interactions with let-7 family microRNAs and let-7-targeted heterochronic genes, hbl-1, lin-41 and lin-42.', 'let-7', 'hbl-1')
# (True, False) ('C. elegans apl-1 shows significant genetic interactions with let-7 family microRNAs and let-7-targeted heterochronic genes, hbl-1, lin-41 and lin-42.', 'let-7', 'lin-41')
# (True, False) ('The data strongly suggested that a regulatory loop between miR-21 and STAT3 might provide an insight into the mechanism of modulating EGFR/STAT3 signaling.', 'miR-21', 'EGFR')
# (True, False) ('The data strongly suggested that a regulatory loop between miR-21 and STAT3 might provide an insight into the mechanism of modulating EGFR/STAT3 signaling.', 'miR-21', 'STAT3')
# (True, False) ("miR-29b downregulates the expression of luciferase through hPGRN or mouse PGRN (mPGRN) 3'UTRs, and the regulation was abolished by mutations in the miR-29b binding site.", 'miR-29b', 'PGRN')
# (True, False) ("Moreover, overexpression of miR-21 in neurons significantly reduced FASLG levels, and introduction of an miR-21 mimic into 293-HEK cells substantially reduced luciferase activity in a reporter system containing the 3'-UTR of Faslg.", 'miR-21', 'Faslg')
# (True, False) ('Taken together, these results suggested that over-express miR-21 could inhibit TMZ-induced apoptosis in U87MG cells, at least in part, by decreasing Bax/Bcl-2 ratio and caspase-3 activity, which highlighted the possibility of miR-21 overexpression in the clinical resistance to chemotherapeutic therapy of TMZ.', 'miR-21', 'Bax')
# (True, False) ('Taken together, these results suggested that over-express miR-21 could inhibit TMZ-induced apoptosis in U87MG cells, at least in part, by decreasing Bax/Bcl-2 ratio and caspase-3 activity, which highlighted the possibility of miR-21 overexpression in the clinical resistance to chemotherapeutic therapy of TMZ.', 'miR-21', 'Bcl-2')
# (True, False) ('Taken together, these results suggested that over-express miR-21 could inhibit TMZ-induced apoptosis in U87MG cells, at least in part, by decreasing Bax/Bcl-2 ratio and caspase-3 activity, which highlighted the possibility of miR-21 overexpression in the clinical resistance to chemotherapeutic therapy of TMZ.', 'miR-21', 'caspase-3')
# (True, False) ('miR-206 mediates these effects at least in part through histone deacetylase 4 and fibroblast growth factor signaling pathways.', 'miR-206', 'histone deacetylase 4')
# Total:      232
#
#
#
#
# T,T 63
# T,F 12
# F,T 75
# F,F 82
# precision 0.84
# recall 0.45652173913043476
# specificity 0.8723404255319149
# f1 0.5915492957746479

# %%
enttree = analyse(
('miR-206 mediates these effects at least in part through histone deacetylase 4 and fibroblast growth factor signaling pathways.', 0, 9)
)
# Out:
# 0 7 0 miR-206 NOUN nsubj mediates 8 set()
# 8 16 1 mediates VERB ROOT mediates 8 set()
# 17 22 2 these DET det effects 23 set()
# 23 30 3 effects NOUN dobj mediates 8 set()
# 31 33 4 at ADP advmod part 43 set()
# 34 39 5 least ADJ mwe at 31 set()
# 40 42 6 in ADP case part 43 set()
# 43 47 7 part NOUN nmod mediates 8 set()
# 48 55 8 through ADP case deacetylase 64 set()
# 56 63 9 histone NOUN compound deacetylase 64 {('GENE_OR_GENE_PRODUCT', 'histone deacetylase 4')}
# 64 75 10 deacetylase NOUN nmod part 43 {('GENE_OR_GENE_PRODUCT', 'histone deacetylase 4')}
# 76 77 11 4 NUM nummod deacetylase 64 {('GENE_OR_GENE_PRODUCT', 'histone deacetylase 4')}
# 78 81 12 and CCONJ cc deacetylase 64 set()
# 82 92 13 fibroblast NOUN compound pathways 117 {('GENE_OR_GENE_PRODUCT', 'fibroblast growth factor')}
# 93 99 14 growth NOUN compound pathways 117 {('GENE_OR_GENE_PRODUCT', 'fibroblast growth factor')}
# 100 106 15 factor NOUN compound pathways 117 {('GENE_OR_GENE_PRODUCT', 'fibroblast growth factor')}
# 107 116 16 signaling NOUN compound pathways 117 set()
# 117 125 17 pathways NOUN conj deacetylase 64 set()
# 125 126 18 . PUNCT punct mediates 8 set()
# miR-206 histone
# miR-206 histone
# Conjuncts [pathways, deacetylase]
# neighbour pathways .
# neighbour pathways None
# Conjunction before fc deacetylase
# fc add children for deacetylase
# fc add children for deacetylase
# Conjuncts [deacetylase, pathways]
# neighbour deacetylase 4
# neighbour deacetylase 4
# Conjunction before fc pathways
# Conjunctions
# deacetylase [through, deacetylase, 4, pathways]
# SDP sent: miR-206 mediates these effects at least in part through histone deacetylase 4 and fibroblast growth factor signaling pathways.
# SDP     : [(miR-206, 'NOUN', 'nsubj', False), (mediates, 'VERB', 'ROOT', False), (part, 'NOUN', 'nmod', False), (deacetylase, 'NOUN', 'nmod', False), (histone, 'NOUN', 'compound', False)]
# 0 [miR-206, mediates, these, effects, at, least, in, part, through, histone, deacetylase, 4, and, fibroblast, growth, factor, signaling, pathways] 18 0 miR-206 mediates these effects at least in part through histone deacetylase 4 and fibroblast growth factor signaling pathways.
# Conjuncts [pathways, deacetylase]
# neighbour pathways .
# neighbour pathways None
# Conjunction before fc deacetylase
# fc add children for deacetylase
# fc add children for deacetylase
# Conjuncts [deacetylase, pathways]
# neighbour deacetylase 4
# neighbour deacetylase 4
# Conjunction before fc pathways
# (True, {'conj': True, 'sdp': True, 'compartment': True, 'context': True, 'passive': False, 'negation': False})
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0971fe24633345febe6c3338f96b0af9-0" class="displacy" width="1490" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">miR-206</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">mediates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">effects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">least</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">through</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">histone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">deacetylase</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">fibroblast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">growth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">factor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">signaling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">pathways.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0971fe24633345febe6c3338f96b0af9-0-0" stroke-width="2px" d="M62,242.0 62,228.66666666666666 115.0,228.66666666666666 115.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0971fe24633345febe6c3338f96b0af9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,244.0 L58,236.0 66,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0971fe24633345febe6c3338f96b0af9-0-1" stroke-width="2px" d="M222,242.0 222,228.66666666666666 275.0,228.66666666666666 275.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0971fe24633345febe6c3338f96b0af9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,244.0 L218,236.0 226,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0971fe24633345febe6c3338f96b0af9-0-2" stroke-width="2px" d="M142,242.0 142,215.33333333333334 278.0,215.33333333333334 278.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0971fe24633345febe6c3338f96b0af9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M278.0,244.0 L282.0,236.0 274.0,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0971fe24633345febe6c3338f96b0af9-0-3" stroke-width="2px" d="M382,242.0 382,202.0 601.0,202.0 601.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0971fe24633345febe6c3338f96b0af9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,244.0 L378,236.0 386,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0971fe24633345febe6c3338f96b0af9-0-4" stroke-width="2px" d="M382,242.0 382,228.66666666666666 435.0,228.66666666666666 435.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0971fe24633345febe6c3338f96b0af9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mwe</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M435.0,244.0 L439.0,236.0 431.0,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0971fe24633345febe6c3338f96b0af9-0-5" stroke-width="2px" d="M542,242.0 542,228.66666666666666 595.0,228.66666666666666 595.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">miR-206 mediates these effects at least in part through
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     histone deacetylase 4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fibroblast growth factor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  signaling pathways.</div></span>

# %%
scoreAnalysis(printCase=(False, True))
# Out:
# (False, True) ('Our data suggests that down-regulation of miRNA-128 may contribute to glioma and GBM, in part, by coordinately up-regulating ARP5 (ANGPTL6), Bmi-1 and E2F-3a, resulting in the proliferation of undifferentiated GBM cells.', 'miRNA-128', 'ARP5')
# (False, True) ('Our data suggests that down-regulation of miRNA-128 may contribute to glioma and GBM, in part, by coordinately up-regulating ARP5 (ANGPTL6), Bmi-1 and E2F-3a, resulting in the proliferation of undifferentiated GBM cells.', 'miRNA-128', 'ANGPTL6')
# (False, True) ('Our data suggests that down-regulation of miRNA-128 may contribute to glioma and GBM, in part, by coordinately up-regulating ARP5 (ANGPTL6), Bmi-1 and E2F-3a, resulting in the proliferation of undifferentiated GBM cells.', 'miRNA-128', 'Bmi-1')
# (False, True) ("Addition of exogenous miRNA-128 to CRL-1690 and CRL-2610 GBM cell lines (a) restored 'homeostatic' ARP5 (ANGPTL6), Bmi-1 and E2F-3a expression, and (b) significantly decreased the proliferation of CRL-1690 and CRL-2610 cell lines.", 'miRNA-128', 'ARP5')
# (False, True) ("Addition of exogenous miRNA-128 to CRL-1690 and CRL-2610 GBM cell lines (a) restored 'homeostatic' ARP5 (ANGPTL6), Bmi-1 and E2F-3a expression, and (b) significantly decreased the proliferation of CRL-1690 and CRL-2610 cell lines.", 'miRNA-128', 'ANGPTL6')
# (False, True) ("Addition of exogenous miRNA-128 to CRL-1690 and CRL-2610 GBM cell lines (a) restored 'homeostatic' ARP5 (ANGPTL6), Bmi-1 and E2F-3a expression, and (b) significantly decreased the proliferation of CRL-1690 and CRL-2610 cell lines.", 'miRNA-128', 'Bmi-1')
# (False, True) ('Three bioinformatics-verified miRNA-128 targets, angiopoietin-related growth factor protein 5 (ARP5; ANGPTL6), a transcription suppressor that promotes stem cell renewal and inhibits the expression of known tumor suppressor genes involved in senescence and differentiation, Bmi-1, and a transcription factor critical for the control of cell-cycle progression, E2F-3a, were found to be up-regulated.', 'miRNA-128', 'angiopoietin-related growth factor protein 5')
# (False, True) ('Three bioinformatics-verified miRNA-128 targets, angiopoietin-related growth factor protein 5 (ARP5; ANGPTL6), a transcription suppressor that promotes stem cell renewal and inhibits the expression of known tumor suppressor genes involved in senescence and differentiation, Bmi-1, and a transcription factor critical for the control of cell-cycle progression, E2F-3a, were found to be up-regulated.', 'miRNA-128', 'ARP5')
# (False, True) ('Three bioinformatics-verified miRNA-128 targets, angiopoietin-related growth factor protein 5 (ARP5; ANGPTL6), a transcription suppressor that promotes stem cell renewal and inhibits the expression of known tumor suppressor genes involved in senescence and differentiation, Bmi-1, and a transcription factor critical for the control of cell-cycle progression, E2F-3a, were found to be up-regulated.', 'miRNA-128', 'ANGPTL6')
# (False, True) ('Three bioinformatics-verified miRNA-128 targets, angiopoietin-related growth factor protein 5 (ARP5; ANGPTL6), a transcription suppressor that promotes stem cell renewal and inhibits the expression of known tumor suppressor genes involved in senescence and differentiation, Bmi-1, and a transcription factor critical for the control of cell-cycle progression, E2F-3a, were found to be up-regulated.', 'miRNA-128', 'Bmi-1')
# (False, True) ('Micro-RNA-128 (miRNA-128) down-regulation in glioblastoma targets ARP5 (ANGPTL6), Bmi-1 and E2F-3a, key regulators of brain cell proliferation.', 'Micro-RNA-128', 'ARP5')
# (False, True) ('Micro-RNA-128 (miRNA-128) down-regulation in glioblastoma targets ARP5 (ANGPTL6), Bmi-1 and E2F-3a, key regulators of brain cell proliferation.', 'Micro-RNA-128', 'ANGPTL6')
# (False, True) ('Micro-RNA-128 (miRNA-128) down-regulation in glioblastoma targets ARP5 (ANGPTL6), Bmi-1 and E2F-3a, key regulators of brain cell proliferation.', 'Micro-RNA-128', 'Bmi-1')
# (False, True) ('Micro-RNA-128 (miRNA-128) down-regulation in glioblastoma targets ARP5 (ANGPTL6), Bmi-1 and E2F-3a, key regulators of brain cell proliferation.', 'miRNA-128', 'ARP5')
# (False, True) ('Micro-RNA-128 (miRNA-128) down-regulation in glioblastoma targets ARP5 (ANGPTL6), Bmi-1 and E2F-3a, key regulators of brain cell proliferation.', 'miRNA-128', 'ANGPTL6')
# (False, True) ('Micro-RNA-128 (miRNA-128) down-regulation in glioblastoma targets ARP5 (ANGPTL6), Bmi-1 and E2F-3a, key regulators of brain cell proliferation.', 'miRNA-128', 'Bmi-1')
# (False, True) ('Reduction of miR-21 induces glioma cell apoptosis via activating caspase 9 and 3.  Extensive data indicate that miR-21 plays a critical role in gliomagenesis, however, knowledge is limited on the mechanism of action of miR-21, including cell proliferation, apoptosis, and migration.', 'miR-21', 'caspase 9')
# (False, True) ("The reduction of the affinity of miR-433 to the 3' UTR would result in increased FGF20 expression and upregulation of alpha-synuclein, which could in turn promote dopaminergic neurons degeneration.", 'miR-433', 'alpha-synuclein')
# (False, True) ('We show that SRF and myocardin regulate a cardiovascular-specific microRNA (miRNA) cluster encoding miR-143 and miR-145.', 'miR-143', 'SRF')
# (False, True) ('We show that SRF and myocardin regulate a cardiovascular-specific microRNA (miRNA) cluster encoding miR-143 and miR-145.', 'miR-145', 'SRF')
# (False, True) ('Using a glioblastoma xenograft model in immune-deficient nude mice, we observe that glioblastoma-derived cell lines in which mir-21 levels are downregulated or Pdcd4 is over-expressed exhibit decreased tumor formation and growth.', 'mir-21', 'Pdcd4')
# (False, True) ('In addition, our data indicate that either downregulation of mir-21 or overexpression of its target, Pdcd4, in glioblastoma-derived cell lines leads to decreased proliferation, increased apoptosis, and decreased colony formation in soft agar.', 'mir-21', 'Pdcd4')
# (False, True) ('We have further identified that miR-145-mediated phenotypic modulation of VSMCs is through its target gene KLF5 and its downstream signaling molecule, myocardin.', 'miR-145', 'KLF5')
# (False, True) ('Endogenous miR-124a expression and the protein expression of three of its targets; IQ motif containing GTPase activating protein 1 (IQGAP1), laminin γ1 (LAMC1) and integrin β1 (ITGB1) were significantly reciprocally associated in the majority of the clinical cases.', 'miR-124a', 'IQGAP1')
# (False, True) ('Endogenous miR-124a expression and the protein expression of three of its targets; IQ motif containing GTPase activating protein 1 (IQGAP1), laminin γ1 (LAMC1) and integrin β1 (ITGB1) were significantly reciprocally associated in the majority of the clinical cases.', 'miR-124a', 'IQ motif containing GTPase activating protein 1')
# (False, True) ('Endogenous miR-124a expression and the protein expression of three of its targets; IQ motif containing GTPase activating protein 1 (IQGAP1), laminin γ1 (LAMC1) and integrin β1 (ITGB1) were significantly reciprocally associated in the majority of the clinical cases.', 'miR-124a', 'laminin γ1')
# (False, True) ('Endogenous miR-124a expression and the protein expression of three of its targets; IQ motif containing GTPase activating protein 1 (IQGAP1), laminin γ1 (LAMC1) and integrin β1 (ITGB1) were significantly reciprocally associated in the majority of the clinical cases.', 'miR-124a', 'LAMC1')
# (False, True) ('Endogenous miR-124a expression and the protein expression of three of its targets; IQ motif containing GTPase activating protein 1 (IQGAP1), laminin γ1 (LAMC1) and integrin β1 (ITGB1) were significantly reciprocally associated in the majority of the clinical cases.', 'miR-124a', 'integrin β1')
# (False, True) ('Endogenous miR-124a expression and the protein expression of three of its targets; IQ motif containing GTPase activating protein 1 (IQGAP1), laminin γ1 (LAMC1) and integrin β1 (ITGB1) were significantly reciprocally associated in the majority of the clinical cases.', 'miR-124a', 'ITGB1')
# (False, True) ('Among the predicted gene targets for mir-146a, the chemokine CCL8/MCP-2 is a ligand for the CCR5 chemokine receptor and a potent inhibitor of CD4/CCR5-mediated HIV-1 entry and replication.', 'mir-146a', 'chemokine CCL8')
# (False, True) ('Among the predicted gene targets for mir-146a, the chemokine CCL8/MCP-2 is a ligand for the CCR5 chemokine receptor and a potent inhibitor of CD4/CCR5-mediated HIV-1 entry and replication.', 'mir-146a', 'MCP-2')
# (False, True) ('Among the predicted gene targets for mir-146a, the chemokine CCL8/MCP-2 is a ligand for the CCR5 chemokine receptor and a potent inhibitor of CD4/CCR5-mediated HIV-1 entry and replication.', 'mir-146a', 'CCR5 chemokine receptor')
# (False, True) ('Among the predicted gene targets for mir-146a, the chemokine CCL8/MCP-2 is a ligand for the CCR5 chemokine receptor and a potent inhibitor of CD4/CCR5-mediated HIV-1 entry and replication.', 'mir-146a', 'CD4')
# (False, True) ('Among the predicted gene targets for mir-146a, the chemokine CCL8/MCP-2 is a ligand for the CCR5 chemokine receptor and a potent inhibitor of CD4/CCR5-mediated HIV-1 entry and replication.', 'mir-146a', 'CCR5')
# (False, True) ('Thus, we hypothesize that modulating ABCG2 expression by targeting miRNA-328 in glioblastoma cancer stem cells could represent a promising strategy for therapeutic manipulation to increase the efficacy of chemotherapeutic agents for glioblastoma, a highly lethal type of cancer.', 'miRNA-328', 'ABCG2')
# (False, True) ('The data strongly suggested that a regulatory loop between miR-21 and STAT3 might provide an insight into the mechanism of modulating EGFR/STAT3 signaling.', 'miR-21', 'STAT3')
# (False, True) ("miR-29b downregulates the expression of luciferase through hPGRN or mouse PGRN (mPGRN) 3'UTRs, and the regulation was abolished by mutations in the miR-29b binding site.", 'miR-29b', 'PGRN')
# (False, True) ('These findings identify miR-29b as a novel posttranscriptional regulator of PGRN expression, raising the possibility that miR-29b or other miRNAs might be targeted therapeutically to increase hPGRN levels in some FTD patients.', 'miR-29b', 'PGRN')
# (False, True) ('Our data indicate that overexpression of miR-21 protects against ischemic neuronal death, and that downregulation of FASLG, a tumor necrosis factor-α family member and an important cell death-inducing ligand whose gene is targeted by miR-21, probably mediates the neuroprotective effect.', 'miR-21', 'FASLG')
# (False, True) ("Moreover, overexpression of miR-21 in neurons significantly reduced FASLG levels, and introduction of an miR-21 mimic into 293-HEK cells substantially reduced luciferase activity in a reporter system containing the 3'-UTR of Faslg.", 'miR-21', 'FASLG')
# (False, True) ('miR-23a regulation of X-linked inhibitor of apoptosis (XIAP) contributes to sex differences in the response to cerebral ischemia.', 'miR-23a', 'X-linked inhibitor of apoptosis')
# (False, True) ('miR-23a regulation of X-linked inhibitor of apoptosis (XIAP) contributes to sex differences in the response to cerebral ischemia.', 'miR-23a', 'XIAP')
# (False, True) ('Transfection of let-7 miRNA reduced expression of pan-RAS, N-RAS, and K-RAS in the glioblastoma cells.', 'let-7', 'pan-RAS')
# (False, True) ('Transfection of let-7 miRNA reduced expression of pan-RAS, N-RAS, and K-RAS in the glioblastoma cells.', 'let-7', 'N-RAS')
# (False, True) ('Transfection of let-7 miRNA reduced expression of pan-RAS, N-RAS, and K-RAS in the glioblastoma cells.', 'let-7', 'K-RAS')
# (False, True) ("Overexpression of mir-7 and mir-153 significantly reduces endogenous alpha-synuclein levels, whereas inhibition of mir-7 and mir-153 enhances translation of a luciferase construct bearing the alpha-synuclein 3'-untranslated region in primary neurons.", 'mir-7', 'alpha-synuclein')
# (False, True) ("Overexpression of mir-7 and mir-153 significantly reduces endogenous alpha-synuclein levels, whereas inhibition of mir-7 and mir-153 enhances translation of a luciferase construct bearing the alpha-synuclein 3'-untranslated region in primary neurons.", 'mir-153', 'alpha-synuclein')
# (False, True) ('We found that the A allele of rs2507800 suppressed angiopoietin-1 translation by facilitating miR-211 binding, but not the T allele.', 'miR-211', 'angiopoietin-1')
# (False, True) ("To test our hypothesis, a predicted microRNA-binding site was found in the 3'-UTR of angiopoietin-1 using bioinformatics; variant rs2507800 was identified to be located in the miR-211-binding site of angiopoietin-1.", 'miR-211', 'angiopoietin-1')
# (False, True) ("Our results provide evidence that the TT genotype (rs2507800) in the 3'-UTR of angiopoietin-1 might reduce the risk of stroke by interfering with miR-211 binding.", 'miR-211', 'angiopoietin-1')
# (False, True) ('These findings indicate that miR-107 contributes to GRN expression regulation with implications for brain disorders.', 'miR-107', 'GRN')
# (False, True) ("miR-107 has been implicated in Alzheimer's disease pathogenesis, and sequence elements in the open reading frame-rather than the 3' untranslated region-of GRN mRNA are recognized by miR-107 and are highly conserved among vertebrate species.", 'miR-107', 'GRN')
# (False, True) ('Glucose supplementation in cultured cells that leads to increased miR-107 levels also results in decreased GRN expression, including changes in cell compartmentation and decreased secretion of GRN protein.', 'miR-107', 'GRN')
# (False, True) ('Glucose supplementation in cultured cells that leads to increased miR-107 levels also results in decreased GRN expression, including changes in cell compartmentation and decreased secretion of GRN protein.', 'miR-107', 'GRN')
# (False, True) ('MiR-21 protected human glioblastoma U87MG cells from chemotherapeutic drug temozolomide induced apoptosis by decreasing Bax/Bcl-2 ratio and caspase-3 activity.', 'MiR-21', 'caspase-3')
# (False, True) ('MiR-21 protected human glioblastoma U87MG cells from chemotherapeutic drug temozolomide induced apoptosis by decreasing Bax/Bcl-2 ratio and caspase-3 activity.', 'MiR-21', 'Bax')
# (False, True) ('MiR-21 protected human glioblastoma U87MG cells from chemotherapeutic drug temozolomide induced apoptosis by decreasing Bax/Bcl-2 ratio and caspase-3 activity.', 'MiR-21', 'Bcl-2')
# (False, True) ('Hypoxia induces microRNA miR-210 in vitro and in vivo ephrin-A3 and neuronal pentraxin 1 are potentially regulated by miR-210.', 'miR-210', 'neuronal pentraxin 1')
# (False, True) ('When overexpressed in macrophages, miR-124 directly inhibited the transcription factor CCAAT/enhancer-binding protein-α (C/EBP-α) and its downstream target PU.1, resulting in transformation of these cells from an activated phenotype into a quiescent CD45(low), major histocompatibility complex (MHC) class II(low) phenotype resembling resting microglia.', 'miR-124', 'enhancer-binding protein-α')
# (False, True) ('When overexpressed in macrophages, miR-124 directly inhibited the transcription factor CCAAT/enhancer-binding protein-α (C/EBP-α) and its downstream target PU.1, resulting in transformation of these cells from an activated phenotype into a quiescent CD45(low), major histocompatibility complex (MHC) class II(low) phenotype resembling resting microglia.', 'miR-124', 'C/EBP-α')
# (False, True) ('We identified putative miR sites in the CDK6 including microRNA 124a, a brain enriched microRNA.', 'microRNA 124a', 'CDK6')
# (False, True) ('These cellular responses are mediated by augmented expression of the direct targets of miR-10b, including BCL2L11/Bim, TFAP2C/AP-2γ, CDKN1A/p21, and CDKN2A/p16, which normally protect cells from uncontrolled growth.', 'miR-10b', 'BCL2L11')
# (False, True) ('These cellular responses are mediated by augmented expression of the direct targets of miR-10b, including BCL2L11/Bim, TFAP2C/AP-2γ, CDKN1A/p21, and CDKN2A/p16, which normally protect cells from uncontrolled growth.', 'miR-10b', 'Bim')
# (False, True) ('These cellular responses are mediated by augmented expression of the direct targets of miR-10b, including BCL2L11/Bim, TFAP2C/AP-2γ, CDKN1A/p21, and CDKN2A/p16, which normally protect cells from uncontrolled growth.', 'miR-10b', 'TFAP2C')
# (False, True) ('These cellular responses are mediated by augmented expression of the direct targets of miR-10b, including BCL2L11/Bim, TFAP2C/AP-2γ, CDKN1A/p21, and CDKN2A/p16, which normally protect cells from uncontrolled growth.', 'miR-10b', 'AP-2γ')
# (False, True) ('These cellular responses are mediated by augmented expression of the direct targets of miR-10b, including BCL2L11/Bim, TFAP2C/AP-2γ, CDKN1A/p21, and CDKN2A/p16, which normally protect cells from uncontrolled growth.', 'miR-10b', 'CDKN1A')
# (False, True) ('These cellular responses are mediated by augmented expression of the direct targets of miR-10b, including BCL2L11/Bim, TFAP2C/AP-2γ, CDKN1A/p21, and CDKN2A/p16, which normally protect cells from uncontrolled growth.', 'miR-10b', 'p21')
# (False, True) ('These cellular responses are mediated by augmented expression of the direct targets of miR-10b, including BCL2L11/Bim, TFAP2C/AP-2γ, CDKN1A/p21, and CDKN2A/p16, which normally protect cells from uncontrolled growth.', 'miR-10b', 'CDKN2A')
# (False, True) ('These cellular responses are mediated by augmented expression of the direct targets of miR-10b, including BCL2L11/Bim, TFAP2C/AP-2γ, CDKN1A/p21, and CDKN2A/p16, which normally protect cells from uncontrolled growth.', 'miR-10b', 'p16')
# (False, True) ('BAG2 levels in cells are under the physiological control of the microRNA miR-128a, which can tune paired helical filament Tau levels in neurons.', 'miR-128a', 'Tau')
# (False, True) ('An inverse correlation has been shown in B cell chronic lymphocytic leukemia (B-CLL) between miR-15a and miR-16-1 expression and the expression levels of arginyl-tRNA synthetase (RARS), an enzyme which associates with the cofactor p43 in the aminoacyl-tRNA synthetase complex.', 'miR-15a', 'arginyl-tRNA synthetase')
# (False, True) ('An inverse correlation has been shown in B cell chronic lymphocytic leukemia (B-CLL) between miR-15a and miR-16-1 expression and the expression levels of arginyl-tRNA synthetase (RARS), an enzyme which associates with the cofactor p43 in the aminoacyl-tRNA synthetase complex.', 'miR-15a', 'RARS')
# (False, True) ('An inverse correlation has been shown in B cell chronic lymphocytic leukemia (B-CLL) between miR-15a and miR-16-1 expression and the expression levels of arginyl-tRNA synthetase (RARS), an enzyme which associates with the cofactor p43 in the aminoacyl-tRNA synthetase complex.', 'miR-16-1', 'arginyl-tRNA synthetase')
# (False, True) ('An inverse correlation has been shown in B cell chronic lymphocytic leukemia (B-CLL) between miR-15a and miR-16-1 expression and the expression levels of arginyl-tRNA synthetase (RARS), an enzyme which associates with the cofactor p43 in the aminoacyl-tRNA synthetase complex.', 'miR-16-1', 'RARS')
# (False, True) ('Variation in the miRNA-433 binding site of FGF20 confers risk for Parkinson disease by overexpression of alpha-synuclein.', 'miRNA-433', 'FGF20')
# Total:      232
#
#
#
#
# T,T 63
# T,F 12
# F,T 75
# F,F 82
# precision 0.84
# recall 0.45652173913043476
# specificity 0.8723404255319149
# f1 0.5915492957746479

# %%
enttree = analyse(
('Variation in the miRNA-433 binding site of FGF20 confers risk for Parkinson disease by overexpression of alpha-synuclein.', 3, 7)
)
# Out:
# 0 9 0 Variation NOUN nsubj confers 49 set()
# 10 12 1 in ADP case site 35 set()
# 13 16 2 the DET det site 35 set()
# 17 26 3 miRNA-433 NOUN amod site 35 set()
# 27 34 4 binding NOUN compound site 35 set()
# 35 39 5 site NOUN nmod Variation 0 set()
# 40 42 6 of ADP case FGF20 43 set()
# 43 48 7 FGF20 NOUN nmod site 35 {('GENE_OR_GENE_PRODUCT', 'FGF20')}
# 49 56 8 confers VERB ROOT confers 49 set()
# 57 61 9 risk NOUN dobj confers 49 set()
# 62 65 10 for ADP case disease 76 set()
# 66 75 11 Parkinson NOUN compound disease 76 set()
# 76 83 12 disease NOUN nmod risk 57 set()
# 84 86 13 by ADP case overexpression 87 set()
# 87 101 14 overexpression NOUN nmod confers 49 set()
# 102 104 15 of ADP case alpha-synuclein 105 set()
# 105 120 16 alpha-synuclein NOUN nmod overexpression 87 {('GENE_OR_GENE_PRODUCT', 'alpha-synuclein')}
# 120 121 17 . PUNCT punct confers 49 set()
# miRNA-433 FGF20
# miRNA-433 FGF20
# Conjunctions
# SDP sent: Variation in the miRNA-433 binding site of FGF20 confers risk for Parkinson disease by overexpression of alpha-synuclein.
# SDP     : [(miRNA-433, 'NOUN', 'amod', False), (site, 'NOUN', 'nmod', False), (FGF20, 'NOUN', 'nmod', False)]
# 0 [Variation, in, the, miRNA-433, binding, site, of, FGF20, confers, risk, for, Parkinson, disease, by, overexpression, of, alpha-synuclein] 17 0 Variation in the miRNA-433 binding site of FGF20 confers risk for Parkinson disease by overexpression of alpha-synuclein.
# Context Fail for Noun Rule
# (True, {'conj': True, 'sdp': True, 'compartment': True, 'context': True, 'passive': False, 'negation': False})
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5e25169b90894468ad7c45b683446bc3-0" class="displacy" width="1410" height="417.0" direction="ltr" style="max-width: none; height: 417.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Variation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">miRNA-433</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">binding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">site</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">FGF20</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">confers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Parkinson</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">disease</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">overexpression</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">alpha-synuclein.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5e25169b90894468ad7c45b683446bc3-0-0" stroke-width="2px" d="M62,282.0 62,188.66666666666669 690.0,188.66666666666669 690.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5e25169b90894468ad7c45b683446bc3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,284.0 L58,276.0 66,276.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5e25169b90894468ad7c45b683446bc3-0-1" stroke-width="2px" d="M142,282.0 142,228.66666666666666 441.0,228.66666666666666 441.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5e25169b90894468ad7c45b683446bc3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,284.0 L138,276.0 146,276.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5e25169b90894468ad7c45b683446bc3-0-2" stroke-width="2px" d="M222,282.0 222,242.0 438.0,242.0 438.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5e25169b90894468ad7c45b683446bc3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,284.0 L218,276.0 226,276.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5e25169b90894468ad7c45b683446bc3-0-3" stroke-width="2px" d="M302,282.0 302,255.33333333333334 435.0,255.33333333333334 435.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5e25169b90894468ad7c45b683446bc3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,284.0 L298,276.0 306,276.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5e25169b90894468ad7c45b683446bc3-0-4" stroke-width="2px" d="M382,282.0 382,268.6666666666667 432.0,268.6666666666667 432.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5e25169b90894468ad7c45b683446bc3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,284.0 L378,276.0 386,276.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5e25169b90894468ad7c45b683446bc3-0-5" stroke-width="2px" d="M62,282.0 62,215.33333333333331 444.0,215.33333333333331 444.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5e25169b90894468ad7c45b683446bc3-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor"
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Variation in the miRNA-433 binding site of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FGF20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  confers risk for Parkinson disease by overexpression of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alpha-synuclein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# .</div></span>

# %%
enttree = analyse(
('Glucose supplementation in cultured cells that leads to increased miR-107 levels also results in decreased GRN expression, including changes in cell compartmentation and decreased secretion of GRN protein.', 9, 15 )
)
# Out:
# 0 7 0 Glucose NOUN compound supplementation 8 {('SIMPLE_CHEMICAL', 'Glucose')}
# 8 23 1 supplementation NOUN nsubj results 86 set()
# 24 26 2 in ADP case cells 36 set()
# 27 35 3 cultured VERB amod cells 36 set()
# 36 41 4 cells NOUN nmod supplementation 8 {('CELL', 'cells')}
# 42 46 5 that DET nsubj leads 47 set()
# 47 52 6 leads VERB acl:relcl cells 36 set()
# 53 55 7 to PART case levels 74 set()
# 56 65 8 increased VERB amod levels 74 set()
# 66 73 9 miR-107 ADJ compound levels 74 {('GENE_OR_GENE_PRODUCT', 'miR-107')}
# 74 80 10 levels NOUN nmod leads 47 set()
# 81 85 11 also ADV advmod results 86 set()
# 86 93 12 results VERB ROOT results 86 set()
# 94 96 13 in ADP case expression 111 set()
# 97 106 14 decreased VERB amod expression 111 set()
# 107 110 15 GRN NOUN compound expression 111 set()
# 111 121 16 expression NOUN nmod results 86 set()
# 121 122 17 , PUNCT punct expression 111 set()
# 123 132 18 including VERB case changes 133 set()
# 133 140 19 changes NOUN nmod expression 111 set()
# 141 143 20 in ADP case compartmentation 149 set()
# 144 148 21 cell NOUN compound compartmentation 149 {('CELL', 'cell')}
# 149 165 22 compartmentation NOUN nmod changes 133 set()
# 166 169 23 and CCONJ cc changes 133 set()
# 170 179 24 decreased VERB amod secretion 180 set()
# 180 189 25 secretion NOUN conj changes 133 set()
# 190 192 26 of ADP case protein 197 set()
# 193 196 27 GRN NOUN compound protein 197 set()
# 197 204 28 protein NOUN nmod secretion 180 set()
# 204 205 29 . PUNCT punct results 86 set()
# miR-107 GRN
# miR-107 GRN
# Conjuncts [secretion, changes]
# neighbour secretion of
# neighbour secretion of
# Conjunction before fc changes
# fc add children for changes
# fc add children for changes
# Conjuncts [changes, secretion]
# neighbour changes in
# neighbour changes in
# Conjunction before fc secretion
# fc add children for secretion
# fc add children for secretion
# Conjunctions
# changes [including, changes, in, compartmentation, decreased, secretion, of, protein]
# SDP sent: Glucose supplementation in cultured cells that leads to increased miR-107 levels also results in decreased GRN expression, including changes in cell compartmentation and decreased secretion of GRN protein.
# SDP     : [(miR-107, 'ADJ', 'compound', False), (levels, 'NOUN', 'nmod', False), (leads, 'VERB', 'acl:relcl', False), (cells, 'NOUN', 'nmod', False), (supplementation, 'NOUN', 'nsubj', False), (results, 'VERB', 'ROOT', False), (expression, 'NOUN', 'nmod', False), (GRN, 'NOUN', 'compound', False)]
# 0 [Glucose, supplementation, in, cultured, cells, that, leads, to, increased, miR-107, levels, also, results, in, decreased, GRN, expression, ,, including, changes, in, cell, compartmentation, and, decreased, secretion, of, GRN, protein] 29 0 Glucose supplementation in cultured cells that leads to increased miR-107 levels also results in decreased GRN expression, including changes in cell compartmentation and decreased secretion of GRN protein.
# Conjuncts [secretion, changes]
# neighbour secretion of
# neighbour secretion of
# Conjunction before fc changes
# fc add children for changes
# fc add children for changes
# Conjuncts [changes, secretion]
# neighbour changes in
# neighbour changes in
# Conjunction before fc secretion
# fc add children for secretion
# fc add children for secretion
# (True, {'conj': True, 'sdp': True, 'compartment': True, 'context': True, 'passive': False, 'negation': False})
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f84527d2e1154a1abd59e72e4e99dcbd-0" class="displacy" width="2290" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Glucose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">supplementation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">cultured</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">cells</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">leads</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">increased</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">miR-107</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">levels</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">results</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">decreased</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">GRN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">expression,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">including</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">changes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">cell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">compartmentation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">decreased</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">secretion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">GRN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">protein.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f84527d2e1154a1abd59e72e4e99dcbd-0-0" stroke-width="2px" d="M62,242.0 62,228.66666666666666 115.0,228.66666666666666 115.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f84527d2e1154a1abd59e72e4e99dcbd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,244.0 L58,236.0 66,236.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f84527d2e1
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Glucose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
#  supplementation in cultured
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cells
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
#  that leads to increased
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     miR-107
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  levels also results in decreased GRN expression, including changes in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
#  compartmentation and decreased secretion of GRN protein.</div></span>

# %%
enttree = analyse(
('Our data suggests that down-regulation of miRNA-128 may contribute to glioma and GBM, in part, by coordinately up-regulating ARP5 (ANGPTL6), Bmi-1 and E2F-3a, resulting in the proliferation of undifferentiated GBM cells.', 6, 20)
)
# Out:
# 0 3 0 Our DET nmod:poss data 4 set()
# 4 8 1 data NOUN nsubj suggests 9 set()
# 9 17 2 suggests VERB ROOT suggests 9 set()
# 18 22 3 that SCONJ mark contribute 56 set()
# 23 38 4 down-regulation NOUN nsubj contribute 56 set()
# 39 41 5 of ADP case miRNA-128 42 set()
# 42 51 6 miRNA-128 NOUN nmod down-regulation 23 set()
# 52 55 7 may VERB aux contribute 56 set()
# 56 66 8 contribute VERB ccomp suggests 9 set()
# 67 69 9 to PART case glioma 70 set()
# 70 76 10 glioma NOUN nmod contribute 56 {('CANCER', 'glioma')}
# 77 80 11 and CCONJ cc glioma 70 set()
# 81 84 12 GBM NOUN conj glioma 70 {('CANCER', 'GBM')}
# 84 85 13 , PUNCT punct glioma 70 set()
# 86 88 14 in ADP case part 89 set()
# 89 93 15 part NOUN nmod contribute 56 set()
# 93 94 16 , PUNCT punct contribute 56 set()
# 95 97 17 by ADP mark up-regulating 111 set()
# 98 110 18 coordinately ADV advmod up-regulating 111 set()
# 111 124 19 up-regulating VERB advcl contribute 56 set()
# 125 129 20 ARP5 NOUN dobj up-regulating 111 {('GENE_OR_GENE_PRODUCT', 'ARP5')}
# 130 131 21 ( PUNCT punct ANGPTL6 131 set()
# 131 138 22 ANGPTL6 NOUN appos ARP5 125 {('GENE_OR_GENE_PRODUCT', 'ANGPTL6')}
# 138 139 23 ) PUNCT punct ANGPTL6 131 set()
# 139 140 24 , PUNCT punct ARP5 125 set()
# 141 146 25 Bmi-1 NOUN conj ARP5 125 {('GENE_OR_GENE_PRODUCT', 'Bmi-1')}
# 147 150 26 and CCONJ cc Bmi-1 141 set()
# 151 157 27 E2F-3a NOUN conj Bmi-1 141 {('ORGANISM', 'E2F-3a')}
# 157 158 28 , PUNCT punct contribute 56 set()
# 159 168 29 resulting VERB xcomp contribute 56 set()
# 169 171 30 in ADP case proliferation 176 set()
# 172 175 31 the DET det proliferation 176 set()
# 176 189 32 proliferation NOUN nmod resulting 159 set()
# 190 192 33 of ADP case cells 214 set()
# 193 209 34 undifferentiated ADJ amod cells 214 {('CELL', 'undifferentiated GBM cells')}
# 210 213 35 GBM NOUN compound cells 214 {('CELL', 'undifferentiated GBM cells')}
# 214 219 36 cells NOUN nmod proliferation 176 {('CELL', 'undifferentiated GBM cells')}
# 219 220 37 . PUNCT punct suggests 9 set()
# miRNA-128 ARP5
# miRNA-128 ARP5
# Conjuncts [GBM, glioma]
# neighbour GBM ,
# neighbour GBM in
# Conjunction before fc glioma
# fc add children for glioma
# Conjuncts [glioma, GBM]
# neighbour glioma and
# neighbour glioma and
# Conjunction before fc GBM
# Conjuncts [Bmi-1, E2F-3a, ARP5]
# neighbour Bmi-1 and
# neighbour Bmi-1 and
# neighbour E2F-3a ,
# neighbour E2F-3a resulting
# Conjunction before fc ARP5
# fc add children for ARP5
# Conjuncts [ARP5, E2F-3a, Bmi-1]
# neighbour ARP5 (
# neighbour ARP5 ANGPTL6
# neighbour E2F-3a ,
# neighbour E2F-3a resulting
# Conjunction before fc Bmi-1
# Conjuncts [ARP5, Bmi-1, E2F-3a]
# neighbour ARP5 (
# neighbour ARP5 ANGPTL6
# neighbour Bmi-1 and
# neighbour Bmi-1 and
# Conjunction before fc E2F-3a
# Conjunctions
# glioma [to, glioma, GBM]
# ARP5 [ARP5, ANGPTL6, Bmi-1, E2F-3a]
# ANGPTL6 [(, )]
# SDP sent: Our data suggests that down-regulation of miRNA-128 may contribute to glioma and GBM, in part, by coordinately up-regulating ARP5 (ANGPTL6), Bmi-1 and E2F-3a, resulting in the proliferation of undifferentiated GBM cells.
# SDP     : [(miRNA-128, 'NOUN', 'nmod', False), (down-regulation, 'NOUN', 'nsubj', False), (contribute, 'VERB', 'ccomp', False), (up-regulating, 'VERB', 'advcl', False), (ARP5, 'NOUN', 'dobj', False)]
# deepcheck connection rule noun found contribute down-regulation [that, down-regulation, of, miRNA-128, may, contribute, to, glioma, and, GBM, ,, in, part, ,, by, coordinately, up-regulating, ARP5, (, ANGPTL6, ), ,, Bmi-1, and, E2F-3a, ,, resulting, in, the, proliferation, of, undifferentiated, GBM, cells]
# deepcheck connection rule [by, coordinately, up-regulating, ARP5, (, ANGPTL6, ), ,, Bmi-1, and, E2F-3a]
# 0 [Our, data, suggests] 3 0 Our data suggests that down-regulation of miRNA-128 may contribute to glioma and GBM, in part, by coordinately up-regulating ARP5 (ANGPTL6), Bmi-1 and E2F-3a, resulting in the proliferation of undifferentiated GBM cells.
# 1 [down-regulation, of, miRNA-128, may, contribute, to, glioma, and, GBM, ,, in, part, ,, by, coordinately, up-regulating, ARP5, (, ANGPTL6, ), ,, Bmi-1, and, E2F-3a] 24 23 down-regulation of miRNA-128 may contribute to glioma and GBM, in part, by coordinately up-regulating ARP5 (ANGPTL6), Bmi-1 and E2F-3a, resulting in the proliferation of undifferentiated GBM cells.
# 2 [resulting, in, the, proliferation, of, undifferentiated, GBM, cells] 8 159 resulting in the proliferation of undifferentiated GBM cells.
# Conjuncts [GBM, glioma]
# neighbour GBM ,
# neighbour GBM in
# Conjunction before fc glioma
# fc add children for glioma
# Conjuncts [glioma, GBM]
# neighbour glioma and
# neighbour glioma and
# Conjunction before fc GBM
# Conjuncts [Bmi-1, E2F-3a, ARP5]
# neighbour Bmi-1 and
# neighbour Bmi-1 and
# neighbour E2F-3a ,
# neighbour E2F-3a resulting
# Conjunction before fc ARP5
# fc add children for ARP5
# Conjuncts [ARP5, E2F-3a, Bmi-1]
# neighbour ARP5 (
# neighbour ARP5 ANGPTL6
# neighbour E2F-3a ,
# neighbour E2F-3a resulting
# Conjunction before fc Bmi-1
# Conjuncts [ARP5, Bmi-1, E2F-3a]
# neighbour ARP5 (
# neighbour ARP5 ANGPTL6
# neighbour Bmi-1 and
# neighbour Bmi-1 and
# Conjunction before fc E2F-3a
# (True, {'conj': True, 'sdp': True, 'compartment': True, 'context': True, 'passive': False, 'negation': False})
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f57d53e50da4491ba3f45cafceb33bc0-0" class="displacy" width="2530" height="457.0" direction="ltr" style="max-width: none; height: 457.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Our</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">suggests</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">down-regulation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">miRNA-128</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">contribute</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">glioma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">GBM,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">part,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">coordinately</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">up-regulating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">ARP5 (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">ANGPTL6),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">Bmi-1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">E2F-3a,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">resulting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">proliferation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">undifferentiated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2370">GBM</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">cells.</tspan>
#     <tspan class="displacy-
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Our data suggests that down-regulation of miRNA-128 may contribute to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     glioma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CANCER</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CANCER</span>
# </mark>
# , in part, by coordinately up-regulating
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ARP5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ANGPTL6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# ),
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bmi-1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     E2F-3a
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
# , resulting in the proliferation of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     undifferentiated GBM cells
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CELL</span>
# </mark>
# .</div></span>
