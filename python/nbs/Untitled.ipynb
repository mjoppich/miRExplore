# %%
# %load_ext autoreload
# %autoreload 1

# %%
from collections import defaultdict
import os, sys
sys.path.insert(0, "/mnt/d/dev/git/miRExplore/python/")


import scispacy
import spacy
from spacy import displacy

nlp = spacy.load('/mnt/d/spacy/models/en_core_sci_lg-0.2.4/en_core_sci_lg/en_core_sci_lg-0.2.4/')

# %%
import textmining.MirGeneRelCheck

# %%
def analyse(testCase):
    relCheck = textmining.MirGeneRelCheck.MirGeneRelCheck()

    doc = nlp(testCase[0])
    
    lWord = doc[testCase[1]]
    rWord = doc[testCase[2]]

    for t in doc:
        print(t.idx, t, t.pos_, t.dep_, t.head, t.head.idx)

    print(lWord, rWord)

    if not "mir" in str(lWord).lower() and not "let" in str(lWord).lower():
        tmp = lWord
        lWord = rWord
        rWord = tmp
        
    print(lWord, rWord)
    
    checkResults = relCheck.checkRelation(doc, lWord, rWord, verbose=True)
    print(checkResults)
    
    displacy.render(doc, style="dep")

# %%
# %aimport textmining.MirGeneRelCheck

testcase = (u"Functional association between miR 124a and CDK6 in medulloblastoma was established using luciferase assays.", 4, 6)

analyse(testcase)
# Out:
# 0 Functional ADJ amod association 11
# 11 association NOUN nsubjpass established 72
# 23 between ADP case miR 31
# 31 miR NOUN nmod association 11
# 35 124a NOUN dep miR 31
# 40 and CCONJ cc 124a 35
# 44 CDK6 NOUN conj 124a 35
# 49 in ADP case medulloblastoma 52
# 52 medulloblastoma NOUN nmod association 11
# 68 was AUX auxpass established 72
# 72 established VERB ROOT established 72
# 84 using VERB xcomp established 72
# 90 luciferase NOUN compound assays 101
# 101 assays NOUN dobj using 84
# 107 . PUNCT punct established 72
# 124a CDK6
# CDK6 124a
# Conjuncts [CDK6, 124a]
# neighbour CDK6 in
# neighbour CDK6 in
# Conjunction before fc 124a
# Conjuncts [124a, CDK6]
# neighbour 124a and
# neighbour 124a and
# Conjunction before fc CDK6
# Conjunctions
# 124a {124a, CDK6}
# SDP sent: Functional association between miR 124a and CDK6 in medulloblastoma was established using luciferase assays.
# SDP     : [(124a, 'NOUN', 'dep', False), (established, 'VERB', 'ROOT', False), (association, 'NOUN', 'nsubjpass', False), (miR, 'NOUN', 'nmod', False), (124a, 'NOUN', 'dep', False)]
# deepcheck connection rule noun found using luciferase [using, luciferase, assays]
# atree [Functional, association, between, miR, 124a, and, CDK6, in, medulloblastoma, was, established, .]
# a elem Functional
# a elem association
# a elem between
# a elem miR
# a elem 124a
# a elem and
# a elem CDK6
# a elem in
# a elem medulloblastoma
# a elem was
# a elem established
# a elem .
# 0 [Functional, association, between, miR, 124a, and, CDK6, in, medulloblastoma, was, established] 11 0 Functional association between miR 124a and CDK6 in medulloblastoma was established using luciferase assays.
# 1 [using, luciferase, assays] 3 84 using luciferase assays.
# Conjuncts [CDK6, 124a]
# neighbour CDK6 in
# neighbour CDK6 in
# Conjunction before fc 124a
# Conjuncts [124a, CDK6]
# neighbour 124a and
# neighbour 124a and
# Conjunction before fc CDK6
# (False, {'conj': False, 'sdp': True, 'compartment': True, 'context': True, 'passive': True, 'negation': False})
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="102e0f701e724b0bb08462fe8b665cbc-0" class="displacy" width="2500" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Functional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">association</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">miR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">124a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">CDK6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">medulloblastoma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">established</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">luciferase</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">assays.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-102e0f701e724b0bb08462fe8b665cbc-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-102e0f701e724b0bb08462fe8b665cbc-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-102e0f701e724b0bb08462fe8b665cbc-0-1" stroke-width="2px" d="M245,352.0 C245,2.0 1800.0,2.0 1800.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-102e0f701e724b0bb08462fe8b665cbc-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-102e0f701e724b0bb08462fe8b665cbc-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-102e0f701e724b0bb08462fe8b665cbc-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-102e0f701e724b0bb08462fe8b665cbc-0-3" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-102e0f701e724b0bb08462fe8b665cbc-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-102e0f701e724b0bb08462fe8b665cbc-0-4" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-102e0f701e724b0bb08462fe8b665cbc-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-102e0f701e724b0bb08462fe8b665cbc-0-5" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-102e0f701e724b0bb08462fe8b665cbc-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-102e0f701e724b0bb08462fe8b665cbc-0-6" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-102e0f701e724b0bb08462fe8b665cbc-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1090.0,354.0 L1098.0,342.0 1082.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-102e0f701e724b0bb08462fe8b665cbc-0-7" stroke-width="2px

# %%
# %aimport textmining.MirGeneRelCheck

testcase = (u"In vitro, anti-miRNA-125b added exogenously to IL-6-stressed NHA cultures attenuated both glial cell proliferation and increased the expression of the cyclin-dependent kinase inhibitor 2A (CDKN2A), a miRNA-125b target and negative regulator of cell growth.", 24, 30)


analyse(testcase)
# Out:
# 0 In X compound vitro 3
# 3 vitro X advmod added 26
# 8 , PUNCT punct added 26
# 10 anti-miRNA-125b NOUN nsubj added 26
# 26 added VERB ROOT added 26
# 32 exogenously ADV advmod added 26
# 44 to PART case cultures 65
# 47 IL-6-stressed ADJ amod cultures 65
# 61 NHA ADJ compound cultures 65
# 65 cultures NOUN nmod added 26
# 74 attenuated VERB conj added 26
# 85 both CCONJ cc:preconj proliferation 101
# 90 glial ADJ amod proliferation 101
# 96 cell NOUN compound proliferation 101
# 101 proliferation NOUN dobj attenuated 74
# 115 and CCONJ cc attenuated 74
# 119 increased VERB conj attenuated 74
# 129 the DET det expression 133
# 133 expression NOUN dobj increased 119
# 144 of ADP case 2A 185
# 147 the DET det 2A 185
# 151 cyclin-dependent ADJ amod 2A 185
# 168 kinase NOUN compound 2A 185
# 175 inhibitor NOUN compound 2A 185
# 185 2A NOUN nmod expression 133
# 188 ( PUNCT punct CDKN2A 189
# 189 CDKN2A NOUN appos 2A 185
# 195 ) PUNCT punct CDKN2A 189
# 196 , PUNCT punct 2A 185
# 198 a DET det target 211
# 200 miRNA-125b NOUN amod target 211
# 211 target NOUN appos 2A 185
# 218 and CCONJ cc target 211
# 222 negative ADJ amod regulator 231
# 231 regulator NOUN conj target 211
# 241 of ADP case growth 249
# 244 cell NOUN compound growth 249
# 249 growth NOUN nmod regulator 231
# 255 . PUNCT punct added 26
# 2A miRNA-125b
# miRNA-125b 2A
# Conjuncts [attenuated, increased, added]
# neighbour attenuated both
# neighbour attenuated both
# neighbour increased the
# neighbour increased the
# Conjunction before fc added
# fc add children for added
# Conjuncts [added, increased, attenuated]
# neighbour added exogenously
# neighbour added exogenously
# neighbour increased the
# neighbour increased the
# Conjunction before fc attenuated
# fc add children for attenuated
# Conjuncts [added, attenuated, increased]
# neighbour added exogenously
# neighbour added exogenously
# neighbour attenuated both
# neighbour attenuated both
# Conjunction before fc increased
# fc add children for increased
# Conjuncts [regulator, target]
# neighbour regulator of
# neighbour regulator of
# Conjunction before fc target
# fc add children for target
# Conjuncts [target, regulator]
# neighbour target and
# neighbour target and
# Conjunction before fc regulator
# fc add children for regulator
# fc add children for regulator
# Conjunctions
# added [added, to, IL-6-stressed, cultures, attenuated, glial, proliferation, increased, expression, of, cyclin-dependent, 2A, CDKN2A, miRNA-125b, target, negative, regulator, of, growth]
# CDKN2A [(, )]
# achildren {miRNA-125b, 2A, target}
# SDP sent: In vitro, anti-miRNA-125b added exogenously to IL-6-stressed NHA cultures attenuated both glial cell proliferation and increased the expression of the cyclin-dependent kinase inhibitor 2A (CDKN2A), a miRNA-125b target and negative regulator of cell growth.
# SDP     : [(2A, 'NOUN', 'nmod', False), (added, 'VERB', 'ROOT', True), (attenuated, 'VERB', 'conj', True), (increased, 'VERB', 'conj', False), (expression, 'NOUN', 'dobj', False), (2A, 'NOUN', 'nmod', False)]
# deep check deps [attenuated]
# 0 [In, vitro, ,, anti-miRNA-125b, added, exogenously, to, IL-6-stressed, NHA, cultures] 10 0 In vitro, anti-miRNA-125b added exogenously to IL-6-stressed NHA cultures attenuated both glial cell proliferation and increased the expression of the cyclin-dependent kinase inhibitor 2A (CDKN2A), a miRNA-125b target and negative regulator of cell growth.
# 1 [attenuated, both, glial, cell, proliferation] 5 74 attenuated both glial cell proliferation and increased the expression of the cyclin-dependent kinase inhibitor 2A (CDKN2A), a miRNA-125b target and negative regulator of cell growth.
# 2 [increased, the, expression, of, the, cyclin-dependent, kinase, inhibitor, 2A, (, CDKN2A, ), ,, a, miRNA-125b, target, and, negative, regulator, of, cell, growth] 22 119 increased the expression of the cyclin-dependent kinase inhibitor 2A (CDKN2A), a miRNA-125b target and negative regulator of cell growth.
# Conjuncts [attenuated, increased, added]
# neighbour attenuated both
# neighbour attenuated both
# neighbour increased the
# neighbour increased the
# Conjunction before fc added
# fc add children for added
# Conjuncts [added, increased, attenuated]
# neighbour added exogenously
# neighbour added exogenously
# neighbour increased the
# neighbour increased the
# Conjunction before fc attenuated
# fc add children for attenuated
# Conjuncts [added, attenuated, increased]
# neighbour added exogenously
# neighbour added exogenously
# neighbour attenuated both
# neighbour attenuated both
# Conjunction before fc increased
# fc add children for increased
# Conjuncts [regulator, target]
# neighbour regulator of
# neighbour regulator of
# Conjunction before fc target
# fc add children for target
# Conjuncts [target, regulator]
# neighbour target and
# neighbour target and
# Conjunction before fc regulator
# fc add children for regulator
# fc add children for regulator
# (True, {'conj': True, 'sdp': True, 'compartment': True, 'context': True, 'passive': False, 'negation': False})
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e78c000271044d1fb661389d25632dfe-0" class="displacy" width="6000" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">vitro,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">anti-miRNA-125b</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">added</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">exogenously</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">IL-6-stressed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">NHA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">cultures</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">attenuated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">glial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">cell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">proliferation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">increased</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">expression</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">cyclin-dependent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">kinase</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">inhibitor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">2A (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">CDKN2A),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">miRNA-125b</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">target</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">negative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">regulator</tspan>
#     <tspan class="displacy-tag"

# %%
doc = nlp(testcase[0])

allTokens = {t.i: t for t in doc}

# %%
[x for x in allTokens[23].children]
# Out:
# [two, encoding]

# %%
t.
# Out:
# Functional association between miR 124a and CDK6 in medulloblastoma was established using luciferase assays.
